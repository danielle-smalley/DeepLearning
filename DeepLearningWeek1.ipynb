# %% [markdown]
# <a href="https://colab.research.google.com/github/danielle-smalley/DeepLearning/blob/main/DeepLearningWeek1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastai duckduckgo_search

# %%
from duckduckgo_search import DDGS
from fastcore.all import *

def search_images(term, max_images=30):
    print(f"Searching for '{term}'")
    with DDGS() as ddgs:
        # generator which yields dicts with:
        # {'title','image','thumbnail','url','height','width','source'}
        search_results = ddgs.images(keywords=term)
        # grap number of max_images urls
        image_urls = [next(search_results).get("image") for _ in range(max_images)]
        # convert to L (functionally extended list class from fastai)
        return L(image_urls)

# example usage:
urls = search_images("black cat images", max_images=10)
print(urls[0])
# Out:
# Searching for 'black cat images'
# https://www.rd.com/wp-content/uploads/2021/01/GettyImages-1175550351.jpg?w=2141

# %%
from fastdownload import download_url
dest = 'blackcat.jpg'
download_url('data:image/jpeg;base64,...', dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x170>

# %%
download_url(search_images('tortie cat photos', max_images=1)[0], 'tortie.jpg', show_progress=False)
Image.open('tortie.jpg').to_thumb(256,256)
# Out:
# Searching for 'tortie cat photos'
# <PIL.Image.Image image mode=RGB size=228x256>

# %%
searches = 'black cat','tortie cat'
path = Path('blackcat_or_tortiecat')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)  # Pause between searches to avoid over-loading server
    download_images(dest, urls=search_images(f'{o} sleeping photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} playing photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for 'black cat photo'
# Searching for 'black cat sleeping photo'
# Searching for 'black cat playing photo'
# Searching for 'tortie cat photo'
# Searching for 'tortie cat sleeping photo'
# Searching for 'tortie cat playing photo'

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 2

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=6)
# Out:
# /usr/local/lib/python3.10/dist-packages/fastai/torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 54.8MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
# ...

# %%
is_blackcat,_,probs = learn.predict(PILImage.create('blackcat.jpg'))
print(f"This is a: {is_blackcat}.")
print(f"Probability it's a black cat: {probs[0]:.4f}")

from fastai.vision.all import *
im = Image.open('blackcat.jpg')
im.to_thumb(256,256)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: black cat.
# Probability it's a black cat: 0.9992
# <PIL.Image.Image image mode=RGB size=256x170>

# %%
is_blackcat,_,probs = learn.predict(PILImage.create('tortie.jpg'))
print(f"This is a: {is_blackcat}.")
print(f"Probability it's a black cat: {probs[0]:.4f}")

Image.open('tortie.jpg').to_thumb(256,256)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: tortie cat.
# Probability it's a black cat: 0.0006
# <PIL.Image.Image image mode=RGB size=228x256>
